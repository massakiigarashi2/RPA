# %% [markdown]
# ###01 - **Base** de Dados no GoogleDrive

# %% [markdown]
# * Primeiro, precisa rodar o código abaixo. Aparecerá um link, basta clicar que irá abrir uma outra página. Selecione a conta do gmail. Aparecerá um código. Basta copiar o código e colar no campo que apareceu neste notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1.1) *Caminho da base de dados*
# * Depois, selecione o ícone da pasta no menu lateral esquerdo do notebook. Existirá uma pasta chamada drive, com os arquivos do seu drive.*texto em itálico* Encontre o caminho **do** csv e adicione na variável path abaixo.

# %%
path = '/content/drive/MyDrive/MovimentoFinanceiroCSV.csv'

# %% [markdown]
# #1.2) Lendo a base de dados
# * Leia o csv com o pandas. Precisa mudar o separador (parâmetro sep) e o encoding.

# %%
import pandas as pd
path = '/content/drive/MyDrive/MovimentoFinanceiroCSV.csv'
df = pd.read_csv(path, sep=';', encoding = "ISO-8859-1")
df
# Out:
#    Movimento Financeiro  ...      Unnamed: 6
# 0                   NaN  ...             NaN
# 1                  Data  ...          Estado
# 2            01/10/2010  ...  Santa Catarina
# 3            01/10/2010  ...  Santa Catarina
# 4            04/10/2010  ...  Santa Catarina
# 5            04/10/2010  ...  Rio de Janeiro
# 6            05/10/2010  ...    Minas Gerais
# 7            06/10/2010  ...       São Paulo
# 8            15/10/2010  ...  Rio de Janeiro
# 9            20/10/2001  ...    Minas Gerais
# 10           25/10/2010  ...       São Paulo
# 11           29/10/2010  ...  Rio de Janeiro
# 12           04/11/2010  ...  Santa Catarina
# 13           09/11/2010  ...  Rio de Janeiro
# 14           17/11/2010  ...    Minas Gerais
# 15           01/12/2010  ...       São Paulo
# 16           03/12/2010  ...  Rio de Janeiro
# 17           10/12/2010  ...    Minas Gerais
# 18           20/12/2010  ...  Rio de Janeiro
# 19           23/12/2010  ...  Rio de Janeiro
# 20           05/01/2011  ...       São Paulo
# 21           07/01/2011  ...       São Paulo
# 22           10/01/2011  ...  Rio de Janeiro
# 23           10/01/2011  ...    Minas Gerais
# 24           18/01/2011  ...    Minas Gerais
# 25           20/01/2011  ...  Santa Catarina
# 26           04/02/2011  ...  Santa Catarina
# 27           08/02/2011  ...  Rio de Janeiro
# 28           15/02/2011  ...  Rio de Janeiro
# 29           21/02/2011  ...       São Paulo
# 30           10/03/2011  ...       São Paulo
# 31           15/03/2011  ...  Rio de Janeiro
# 32           21/03/2011  ...  Rio de Janeiro
# 33           25/03/2011  ...    Minas Gerais
# 34           25/03/2011  ...    Minas Gerais
# 35           25/03/2011  ...  Santa Catarina
# 36           01/04/2011  ...  Rio de Janeiro
# 37           05/04/2011  ...    Minas Gerais
# 38           05/04/2011  ...       São Paulo
# 39           06/04/2011  ...  Rio de Janeiro
# 40           08/04/2011  ...    Minas Gerais
# 41           11/04/2011  ...       São Paulo
# 42           03/05/2011  ...  Rio de Janeiro
# 43           05/05/2011  ...  Santa Catarina
# 44           05/05/2011  ...  Rio de Janeiro
# 45           10/05/2011  ...    Minas Gerais
# 46           10/05/2011  ...       São Paulo
# 47           18/05/2011  ...  Santa Catarina
# 48           20/05/2011  ...  Rio de Janeiro
# 49           20/05/2011  ...    Minas Gerais
# 50           20/05/2011  ...       São Paulo
# 51           30/05/2011  ...  Rio de Janeiro
# 52           30/05/2011  ...    Minas Gerais
# 53           10/06/2011  ...       São Paulo
# 54           10/06/2011  ...  Rio de Janeiro
#
# [55 rows x 7 columns]

# %% [markdown]
# * Para alterar e fazer com que os nomes da coluna apareçam na linha 1 (Data, Amostra ...), use as linhas de código a seguir:

# %%
names = df.iloc[1, :].values
df = df.iloc[2:, :]
df.columns = names
df
# Out:
#           Data                      Projeto  ...             Valor           Estado
# 2   01/10/2010         Mineradora Crescente  ...     R$ 380.000,00   Santa Catarina
# 3   01/10/2010         Mineradora Crescente  ...   R$ 1.200.000,00   Santa Catarina
# 4   04/10/2010         Mineradora Crescente  ...     R$ 300.000,00   Santa Catarina
# 5   04/10/2010               Gasoduto Oeste  ...   R$ 3.000.000,00   Rio de Janeiro
# 6   05/10/2010        Siderúrgica Horizonte  ...   R$ 4.300.000,00     Minas Gerais
# 7   06/10/2010          Fertilizantes Clima  ...     R$ 600.000,00        São Paulo
# 8   15/10/2010  Água Preta Telecomunicações  ...     R$ 326.000,00   Rio de Janeiro
# 9   20/10/2001        Siderúrgica Horizonte  ...     R$ 213.000,00     Minas Gerais
# 10  25/10/2010          Fertilizantes Clima  ...     R$ 900.000,00        São Paulo
# 11  29/10/2010  Água Preta Telecomunicações  ...      R$ 98.000,00   Rio de Janeiro
# 12  04/11/2010         Mineradora Crescente  ...     R$ 313.000,00   Santa Catarina
# 13  09/11/2010               Gasoduto Oeste  ...     R$ 125.000,00   Rio de Janeiro
# 14  17/11/2010        Siderúrgica Horizonte  ...       R$ 7.200,00     Minas Gerais
# 15  01/12/2010          Fertilizantes Clima  ...      R$ 40.000,00        São Paulo
# 16  03/12/2010  Água Preta Telecomunicações  ...     R$ 178.000,00   Rio de Janeiro
# 17  10/12/2010        Siderúrgica Horizonte  ...     R$ 380.000,00     Minas Gerais
# 18  20/12/2010  Água Preta Telecomunicações  ...      R$ 53.000,00   Rio de Janeiro
# 19  23/12/2010  Água Preta Telecomunicações  ...     R$ 400.000,00   Rio de Janeiro
# 20  05/01/2011          Fertilizantes Clima  ...     R$ 230.000,00        São Paulo
# 21  07/01/2011          Fertilizantes Clima  ...     R$ 178.000,00        São Paulo
# 22  10/01/2011               Gasoduto Oeste  ...     R$ 300.000,00   Rio de Janeiro
# 23  10/01/2011        Siderúrgica Horizonte  ...     R$ 400.000,00     Minas Gerais
# 24  18/01/2011        Siderúrgica Horizonte  ...     R$ 123.000,00     Minas Gerais
# 25  20/01/2011         Mineradora Crescente  ...     R$ 450.000,00   Santa Catarina
# 26  04/02/2011         Mineradora Crescente  ...     R$ 230.000,00   Santa Catarina
# 27  08/02/2011               Gasoduto Oeste  ...     R$ 670.000,00   Rio de Janeiro
# 28  15/02/2011               Gasoduto Oeste  ...     R$ 230.000,00   Rio de Janeiro
# 29  21/02/2011          Fertilizantes Clima  ...       R$ 5.600,00        São Paulo
# 30  10/03/2011          Fertilizantes Clima  ...     R$ 111.000,00        São Paulo
# 31  15/03/2011  Água Preta Telecomunicações  ...     R$ 211.000,00   Rio de Janeiro
# 32  21/03/2011  Água Preta Telecomunicações  ...     R$ 890.000,00   Rio de Janeiro
# 33  25/03/2011        Siderúrgica Horizonte  ...     R$ 390.000,00     Minas Gerais
# 34  25/03/2011        Siderúrgica Horizonte  ...     R$ 120.000,00     Minas Gerais
# 35  25/03/2011         Mineradora Crescente  ...     R$ 430.000,00   Santa Catarina
# 36  01/04/2011               Gasoduto Oeste  ...     R$ 210.000,00   Rio de Janeiro
# 37  05/04/2011        Siderúrgica Horizonte  ...     R$ 410.000,00     Minas Gerais
# 38  05/04/2011          Fertilizantes Clima  ...     R$ 380.000,00        São Paulo
# 39  06/04/2011  Água Preta Telecomunicações  ...     R$ 111.000,00   Rio de Janeiro
# 40  08/04/2011        Siderúrgica Horizonte  ...     R$ 135.000,00     Minas Gerais
# 41  11/04/2011          Fertilizantes Clima  ...     R$ 129.000,00        São Paulo
# 42  03/05/2011  Água Preta Telecomunicações  ...     R$ 382.000,00   Rio de Janeiro
# 43  05/05/2011         Mineradora Crescente  ...     R$ 200.000,00   Santa Catarina
# 44  05/05/2011               Gasoduto Oeste  ...     R$ 185.000,00   Rio de Janeiro
# 45  10/05/2011        Siderúrgica Horizonte  ...     R$ 560.000,00     Minas Gerais
# 46  10/05/2011          Fertilizantes Clima  ...      R$ 78.000,00        São Paulo
# 47  18/05/2011         Mineradora Crescente  ...     R$ 590.000,00   Santa Catarina
# 48  20/05/2011               Gasoduto Oeste  ...     R$ 760.000,00   Rio de Janeiro
# 49  20/05/2011        Siderúrgica Horizonte  ...     R$ 210.000,00     Minas Gerais
# 50  20/05/2011          Fertilizantes Clima  ...     R$ 133.000,00        São Paulo
# 51  30/05/2011  Água Preta Telecomunicações  ...     R$ 231.000,00   Rio de Janeiro
# 52  30/05/2011        Siderúrgica Horizonte  ...     R$ 121.000,00     Minas Gerais
# 53  10/06/2011          Fertilizantes Clima  ...     R$ 113.000,00        São Paulo
# 54  10/06/2011  Água Preta Telecomunicações  ...     R$ 117.000,00   Rio de Janeiro
#
# [53 rows x 7 columns]

# %%
names
# Out:
# array(['Data', 'Projeto', 'Item', 'Categoria', 'E/S', ' Valor ', 'Estado'],
#       dtype=object)

# %% [markdown]
# #1.3) Metodos **HEAD** e **TAIL**

# %%
df.head(3)
# Out:
#          Data               Projeto  ...             Valor           Estado
# 2  01/10/2010  Mineradora Crescente  ...     R$ 380.000,00   Santa Catarina
# 3  01/10/2010  Mineradora Crescente  ...   R$ 1.200.000,00   Santa Catarina
# 4  04/10/2010  Mineradora Crescente  ...     R$ 300.000,00   Santa Catarina
#
# [3 rows x 7 columns]

# %%
df.tail(5)
# Out:
#           Data                      Projeto  ...           Valor           Estado
# 50  20/05/2011          Fertilizantes Clima  ...   R$ 133.000,00        São Paulo
# 51  30/05/2011  Água Preta Telecomunicações  ...   R$ 231.000,00   Rio de Janeiro
# 52  30/05/2011        Siderúrgica Horizonte  ...   R$ 121.000,00     Minas Gerais
# 53  10/06/2011          Fertilizantes Clima  ...   R$ 113.000,00        São Paulo
# 54  10/06/2011  Água Preta Telecomunicações  ...   R$ 117.000,00   Rio de Janeiro
#
# [5 rows x 7 columns]

# %% [markdown]
# #1.4) Métodos **DESCRIBE** e **INFO**
# describe () é usado para gerar estatísticas descritivas dos dados em um DataFrame ou Série do Pandas. Ele resume a tendência central e a dispersão do conjunto de dados. describe () ajuda a obter uma visão geral rápida do conjunto de dados.
#
# O método INFO também serve para obter informações sobre o dataframe

# %%
df.describe()
# Out:
#               Data                Projeto  ...           Valor           Estado
# count           53                     53  ...               53              53
# unique          41                      5  ...               44               4
# top     20/05/2011  Siderúrgica Horizonte  ...   R$ 230.000,00   Rio de Janeiro
# freq             3                     13  ...                3              19
#
# [4 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 2 to 54
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data       53 non-null     object
#  1   Projeto    53 non-null     object
#  2   Item       53 non-null     object
#  3   Categoria  53 non-null     object
#  4   E/S        53 non-null     object
#  5    Valor     53 non-null     object
#  6   Estado     53 non-null     object
# dtypes: object(7)
# memory usage: 3.0+ KB

# %% [markdown]
# #1.5) Método **memory_usage()**
# memory_usage () retorna uma série Pandas com o uso de memória de cada coluna (em bytes) em um DataFrame Pandas. Ao especificar o atributo deep como True, podemos saber o espaço real que está sendo ocupado por cada coluna. Mais detalhes sobre memory_usage () podem ser encontrados aqui.
#
# O uso de memória de cada coluna foi fornecido como saída em uma série Pandas. É importante saber o uso de memória de um DataFrame, para que você possa resolver erros como MemoryError em Python.

# %%
df.memory_usage(deep=True)
# Out:
# Index         132
# Data         3551
# Projeto      4687
# Item         4715
# Categoria    4519
# E/S          4008
#  Valor       3814
# Estado       3965
# dtype: int64

# %% [markdown]
# #1.6) Método **loc[:]**
# Ajuda a acessar um grupo de linhas e colunas em um conjunto de dados, uma fatia do conjunto de dados, conforme nossa necessidade. Por exemplo, se quisermos apenas as 2 últimas linhas e as 3 primeiras colunas de um conjunto de dados, podemos acessá-los com a ajuda de loc [:]. Também podemos acessar linhas e colunas com base em rótulos em vez de número de linha e coluna.

# %%
df.loc[29:31, ['Data', 'Projeto', 'Categoria']]
# Out:
#           Data                      Projeto                         Categoria
# 29  21/02/2011          Fertilizantes Clima  Despesas Gerais De Administração
# 30  10/03/2011          Fertilizantes Clima          Pagamento De Empréstimos
# 31  15/03/2011  Água Preta Telecomunicações                   Compras À Vista

# %% [markdown]
# #1.7) Método **value_counts**
# value_counts () retorna uma série Pandas contendo as contagens de valores únicos. Considere um conjunto de dados que contém informações de clientes sobre 5.000 clientes de uma empresa. value_counts () nos ajudará a identificar o número de ocorrências de cada valor único em uma série. Ele pode ser aplicado a colunas contendo dados como Estado, Indústria de emprego ou idade dos clientes.

# %%
contagemEntradasSaidas = df['E/S'].value_counts()
contagemEntradasSaidas
# Out:
# Saída      28
# Entrada    25
# Name: E/S, dtype: int64

# %%
contagemProjetos = df['Projeto'].value_counts()
contagemProjetos
# Out:
# Siderúrgica Horizonte          13
# Fertilizantes Clima            12
# Água Preta Telecomunicações    11
# Mineradora Crescente            9
# Gasoduto Oeste                  8
# Name: Projeto, dtype: int64

# %%
contagemEstados = df['Estado'].value_counts()
contagemEstados
# Out:
# Rio de Janeiro    19
# Minas Gerais      13
# São Paulo         12
# Santa Catarina     9
# Name: Estado, dtype: int64

# %% [markdown]
# #1.8) **Método .Keys()** para obter rótulo dos gráficos
#
# A partir do arquivo ***categoricalVariables.ipynb*** aprendemos como criar gráficos para variáveis categóricas
# Mais especificamente, aprendemos a utilizar o **método .keys() **de um dataframe e criar uma lista de nomes que serão utilizados nos rótulos dos gráficos
#
# O **método keys()** retorna um objeto Index com os nomes das colunas. O objeto Index é como uma lista, com os nomes das colunas como itens da lista.

# %%
import matplotlib.pyplot as plt

namesEstados = list(contagemEstados.keys())
namesEstados[0] = 'RJ'
namesEstados[1] = 'MG'
namesEstados[2] = 'SP'
namesEstados[3] = 'SC'

fig, axs = plt.subplots(1, 4, figsize=(9, 3), sharey=True)
axs[0].bar(namesEstados, contagemEstados)
axs[1].scatter(namesEstados, contagemEstados)
axs[2].plot(namesEstados, contagemEstados)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
contagemEstados.values[0]
# Out:
# 19

# %%
contagemEstados['quantidade'] = df['Estado'].value_counts()

# %%
df.loc[:, 'Estado'].hist()

# %%
import pandas as pd
import plotly.express as px

path = '/content/drive/MyDrive/MovimentoFinanceiroCSV.csv'
df = pd.read_csv(path, sep=';', encoding = "ISO-8859-1")

df

names = df.iloc[1, :].values
df = df.iloc[2:, :]
df.columns = names

fig1 = px.line(df, x = 'Projeto', y = ' Valor ', title='Gráfico de linha')
fig1.show()

fig2 = px.bar(df, x = 'Projeto', y = ' Valor ', title='Gráfico de Barras')
fig2.show()

fig3 = px.scatter(df, x = 'Projeto', y = ' Valor ', title='Gráfico de Barras')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e83754f3-c972-43f6-b554-76a4cf4e32e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e83754f3-c972-43f6-b554-76a4cf4e32e7")) {
#                     Plotly.newPlot(
#                         'e83754f3-c972-43f6-b554-76a4cf4e32e7',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Projeto=%{x}<br> Valor =%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["Mineradora Crescente", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Fertilizantes Clima", "Fertilizantes Clima", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Gasoduto Oeste", "Fertilizantes Clima", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es"], "xaxis": "x", "y": [" R$ 380.000,00 ", " R$ 1.200.000,00 ", " R$ 300.000,00 ", " R$ 3.000.000,00 ", " R$ 4.300.000,00 ", " R$ 600.000,00 ", " R$ 326.000,00 ", " R$ 213.000,00 ", " R$ 900.000,00 ", " R$ 98.000,00 ", " R$ 313.000,00 ", " R$ 125.000,00 ", " R$ 7.200,00 ", " R$ 40.000,00 ", " R$ 178.000,00 ", " R$ 380.000,00 ", " R$ 53.000,00 ", " R$ 400.000,00 ", " R$ 230.000,00 ", " R$ 178.000,00 ", " R$ 300.000,00 ", " R$ 400.000,00 ", " R$ 123.000,00 ", " R$ 450.000,00 ", " R$ 230.000,00 ", " R$ 670.000,00 ", " R$ 230.000,00 ", " R$ 5.600,00 ", " R$ 111.000,00 ", " R$ 211.000,00 ", " R$ 890.000,00 ", " R$ 390.000,00 ", " R$ 120.000,00 ", " R$ 430.000,00 ", " R$ 210.000,00 ", " R$ 410.000,00 ", " R$ 380.000,00 ", " R$ 111.000,00 ", " R$ 135.000,00 ", " R$ 129.000,00 ", " R$ 382.000,00 ", " R$ 200.000,00 ", " R$ 185.000,00 ", " R$ 560.000,00 ", " R$ 78.000,00 ", " R$ 590.000,00 ", " R$ 760.000,00 ", " R$ 210.000,00 ", " R$ 133.000,00 ", " R$ 231.000,00 ", " R$ 121.000,00 ", " R$ 113.000,00 ", " R$ 117.000,00 "], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="21927912-efea-4dce-97fe-7cb0736fdcd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("21927912-efea-4dce-97fe-7cb0736fdcd5")) {
#                     Plotly.newPlot(
#                         '21927912-efea-4dce-97fe-7cb0736fdcd5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Projeto=%{x}<br> Valor =%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Mineradora Crescente", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Fertilizantes Clima", "Fertilizantes Clima", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Gasoduto Oeste", "Fertilizantes Clima", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es"], "xaxis": "x", "y": [" R$ 380.000,00 ", " R$ 1.200.000,00 ", " R$ 300.000,00 ", " R$ 3.000.000,00 ", " R$ 4.300.000,00 ", " R$ 600.000,00 ", " R$ 326.000,00 ", " R$ 213.000,00 ", " R$ 900.000,00 ", " R$ 98.000,00 ", " R$ 313.000,00 ", " R$ 125.000,00 ", " R$ 7.200,00 ", " R$ 40.000,00 ", " R$ 178.000,00 ", " R$ 380.000,00 ", " R$ 53.000,00 ", " R$ 400.000,00 ", " R$ 230.000,00 ", " R$ 178.000,00 ", " R$ 300.000,00 ", " R$ 400.000,00 ", " R$ 123.000,00 ", " R$ 450.000,00 ", " R$ 230.000,00 ", " R$ 670.000,00 ", " R$ 230.000,00 ", " R$ 5.600,00 ", " R$ 111.000,00 ", " R$ 211.000,00 ", " R$ 890.000,00 ", " R$ 390.000,00 ", " R$ 120.000,00 ", " R$ 430.000,00 ", " R$ 210.000,00 ", " R$ 410.000,00 ", " R$ 380.000,00 ", " R$ 111.000,00 ", " R$ 135.000,00 ", " R$ 129.000,00 ", " R$ 382.000,00 ", " R$ 200.000,00 ", " R$ 185.000,00 ", " R$ 560.000,00 ", " R$ 78.000,00 ", " R$ 590.000,00 ", " R$ 760.000,00 ", " R$ 210.000,00 ", " R$ 133.000,00 ", " R$ 231.000,00 ", " R$ 121.000,00 ", " R$ 113.000,00 ", " R$ 117.000,00 "], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0dc18302-2c68-4cb8-ad96-cd98b09e7301" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0dc18302-2c68-4cb8-ad96-cd98b09e7301")) {
#                     Plotly.newPlot(
#                         '0dc18302-2c68-4cb8-ad96-cd98b09e7301',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Projeto=%{x}<br> Valor =%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["Mineradora Crescente", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Fertilizantes Clima", "Fertilizantes Clima", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Mineradora Crescente", "Gasoduto Oeste", "Gasoduto Oeste", "Fertilizantes Clima", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Sider\u00fargica Horizonte", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "Mineradora Crescente", "Gasoduto Oeste", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es", "Sider\u00fargica Horizonte", "Fertilizantes Clima", "\u00c1gua Preta Telecomunica\u00e7\u00f5es"], "xaxis": "x", "y": [" R$ 380.000,00 ", " R$ 1.200.000,00 ", " R$ 300.000,00 ", " R$ 3.000.000,00 ", " R$ 4.300.000,00 ", " R$ 600.000,00 ", " R$ 326.000,00 ", " R$ 213.000,00 ", " R$ 900.000,00 ", " R$ 98.000,00 ", " R$ 313.000,00 ", " R$ 125.000,00 ", " R$ 7.200,00 ", " R$ 40.000,00 ", " R$ 178.000,00 ", " R$ 380.000,00 ", " R$ 53.000,00 ", " R$ 400.000,00 ", " R$ 230.000,00 ", " R$ 178.000,00 ", " R$ 300.000,00 ", " R$ 400.000,00 ", " R$ 123.000,00 ", " R$ 450.000,00 ", " R$ 230.000,00 ", " R$ 670.000,00 ", " R$ 230.000,00 ", " R$ 5.600,00 ", " R$ 111.000,00 ", " R$ 211.000,00 ", " R$ 890.000,00 ", " R$ 390.000,00 ", " R$ 120.000,00 ", " R$ 430.000,00 ", " R$ 210.000,00 ", " R$ 410.000,00 ", " R$ 380.000,00 ", " R$ 111.000,00 ", " R$ 135.000,00 ", " R$ 129.000,00 ", " R$ 382.000,00 ", " R$ 200.000,00 ", " R$ 185.000,00 ", " R$ 560.000,00 ", " R$ 78.000,00 ", " R$ 590.000,00 ", " R$ 760.000,00 ", " R$ 210.000,00 ", " R$ 133.000,00 ", " R$ 231.000,00 ", " R$ 121.000,00 ", " R$ 113.000,00 ", " R$ 117.000,00 "], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
import matplotlib.pyplot
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho']
valores = [105235, 107697, 110256, 109236, 108859, 109986]

# %%
matplotlib.pyplot.plot(meses, valores)
matplotlib.pyplot.show()

# %% [markdown]
# #1.9) Método **ylim()**
# os valores no nosso eixo Y são muito próximos um dos outros. Por isso, qualquer mudança nos valores para mais, ou para menos, podem causar distorções no gráfico.
# Para evitar um pouco esse comportamento, podemos mudar os valores da base e do topo do eixo Y, ou seja, podemos alterar seu limite
# usando o método

# %%
matplotlib.pyplot.plot(meses, valores)
matplotlib.pyplot.ylim(100000, 120000)
matplotlib.pyplot.show()

# %% [markdown]
# #1.10) TÍTULO NO GRÁFICO E NOS EIXOS
# ## Para detalhar as informações no gráfico

# %%
matplotlib.pyplot.title('Faturamento no primeiro semestre de 2017')
matplotlib.pyplot.xlabel('Meses')
matplotlib.pyplot.ylabel('Faturamento em R$')
matplotlib.pyplot.plot(meses, valores)
matplotlib.pyplot.ylim(100000, 120000)
matplotlib.pyplot.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

y = 200 + np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 195, where=(y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# #02 - **Referências Bibliográficas**
# #https://plotly.com/python/plot-data-from-csv/
# #https://www.w3schools.com/python/pandas/ref_df_keys.asp
# #https://www.w3schools.com/python/pandas/pandas_cleaning.asp
